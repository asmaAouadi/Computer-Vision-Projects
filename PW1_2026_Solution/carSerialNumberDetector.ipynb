# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# code
# 1- Charger CSV
# 2️- Charger toutes les images train
# 3️- Calculer et stocker descripteurs
# 4️- Quand query arrive :
#        - calculer descripteurs
#        - comparer avec toute la base
#        - choisir meilleur score
#        - afficher résultat
