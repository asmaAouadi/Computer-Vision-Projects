# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# we import the images left and right
img1 = cv2.imread( 'PW4_solution\img7.jpg', 0) 
img2 = cv2.imread( 'PW4_solution\img8.jpg', 0) 

# we resize 20%
img1 = cv2.resize(img1 , (0,0) , 0.2 , interpolation = cv2.INTER_CUBIC)
img2 = cv2.resize(img2 , (0,0) , 0.2 ,  interpoplation =  cv2.INTER_CUBIC)

#int sift
sift = cv2.SIFT.create()

desc1 , kp1 = sift(img1 , 0)
desc2 ,  kp2 = sift(img2 , 0)

goods = []
pts = []
pts2 = []
